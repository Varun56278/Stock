# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv(r'C:\Users\sr528\OneDrive\Desktop\zm\GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns

# %%
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date

# %%
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index

# %%
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

# %%
ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()
# Out:
# C:\Users\sr528\AppData\Local\Temp\ipykernel_5632\3510813950.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 5s 50ms/step - loss: 0.0106 - mean_absolute_error: 0.0730 - val_loss: 0.0326 - val_mean_absolute_error: 0.1618
# Epoch 2/80
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0010 - mean_absolute_error: 0.0257 - val_loss: 0.0077 - val_mean_absolute_error: 0.0745
# Epoch 3/80
# 30/30 [==============================] - 1s 30ms/step - loss: 5.7537e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0035 - val_mean_absolute_error: 0.0470
# Epoch 4/80
# 30/30 [==============================] - 1s 31ms/step - loss: 4.8990e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0037 - val_mean_absolute_error: 0.0490
# Epoch 5/80
# 30/30 [==============================] - 1s 29ms/step - loss: 4.5626e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0034 - val_mean_absolute_error: 0.0468
# Epoch 6/80
# 30/30 [==============================] - 1s 29ms/step - loss: 4.4612e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0030 - val_mean_absolute_error: 0.0437
# Epoch 7/80
# 30/30 [==============================] - 1s 29ms/step - loss: 4.2490e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 8/80
# 30/30 [==============================] - 1s 30ms/step - loss: 4.3136e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0046 - val_mean_absolute_error: 0.0560
# Epoch 9/80
# 30/30 [==============================] - 1s 29ms/step - loss: 3.9706e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0048 - val_mean_absolute_error: 0.0563
# Epoch 10/80
# 30/30 [==============================] - 1s 28ms/step - loss: 3.6143e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0072 - val_mean_absolute_error: 0.0714
# Epoch 11/80
# 30/30 [==============================] - 1s 29ms/step - loss: 3.7106e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0054 - val_mean_absolute_error: 0.0593
# Epoch 12/80
# 30/30 [==============================] - 1s 31ms/step - loss: 3.1517e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0072 - val_mean_absolute_error: 0.0685
# Epoch 13/80
# 30/30 [==============================] - 1s 31ms/step - loss: 3.4397e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0053 - val_mean_absolute_error: 0.0554
# Epoch 14/80
# 30/30 [==============================] - 1s 31ms/step - loss: 3.4688e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0068 - val_mean_absolute_error: 0.0633
# Epoch 15/80
# 30/30 [==============================] - 1s 40ms/step - loss: 3.7501e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0066 - val_mean_absolute_error: 0.0622
# Epoch 16/80
# 30/30 [==============================] - 1s 34ms/step - loss: 3.5248e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0067 - val_mean_absolute_error: 0.0626
# Epoch 17/80
# 30/30 [==============================] - 1s 35ms/step - loss: 3.0816e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0100 - val_mean_absolute_error: 0.0813
# Epoch 18/80
# 30/30 [==============================] - 1s 32ms/step - loss: 3.0483e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0093 - val_mean_absolute_error: 0.0759
# Epoch 19/80
# 30/30 [==============================] - 1s 32ms/step - loss: 3.0310e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0124 - val_mean_absolute_error: 0.0883
# Epoch 20/80
# 30/30 [==============================] - 1s 32ms/step - loss: 2.9447e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0094 - val_mean_absolute_error: 0.0767
# Epoch 21/80
# 30/30 [==============================] - 1s 33ms/step - loss: 2.9969e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0212 - val_mean_absolute_error: 0.1254
# Epoch 22/80
# 30/30 [==============================] - 2s 70ms/step - loss: 3.6327e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0062 - val_mean_absolute_error: 0.0572
# Epoch 23/80
# 30/30 [==============================] - 2s 80ms/step - loss: 2.8389e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0086 - val_mean_absolute_error: 0.0709
# Epoch 24/80
# 30/30 [==============================] - 2s 80ms/step - loss: 2.9419e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0096 - val_mean_absolute_error: 0.0762
# Epoch 25/80
# 30/30 [==============================] - 2s 80ms/step - loss: 2.8176e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0086 - val_mean_absolute_error: 0.0723
# Epoch 26/80
# 30/30 [==============================] - 2s 75ms/step - loss: 2.8592e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0077 - val_mean_absolute_error: 0.0659
# Epoch 27/80
# 30/30 [==============================] - 2s 75ms/step - loss: 2.8103e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0084 - val_mean_absolute_error: 0.0688
# Epoch 28/80
# 30/30 [==============================] - 2s 72ms/step - loss: 2.6810e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0060 - val_mean_absolute_error: 0.0583
# Epoch 29/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.4435e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0102 - val_mean_absolute_error: 0.0782
# Epoch 30/80
# 30/30 [==============================] - 2s 72ms/step - loss: 2.5791e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0055 - val_mean_absolute_error: 0.0533
# Epoch 31/80
# 30/30 [==============================] - 2s 72ms/step - loss: 2.4119e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0080 - val_mean_absolute_error: 0.0674
# Epoch 32/80
# 30/30 [==============================] - 2s 70ms/step - loss: 2.6562e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0079 - val_mean_absolute_error: 0.0658
# Epoch 33/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.3035e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0048 - val_mean_absolute_error: 0.0474
# Epoch 34/80
# 30/30 [==============================] - 2s 71ms/step - loss: 2.3786e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0076 - val_mean_absolute_error: 0.0668
# Epoch 35/80
# 30/30 [==============================] - 2s 71ms/step - loss: 2.4748e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0074 - val_mean_absolute_error: 0.0643
# Epoch 36/80
# 30/30 [==============================] - 2s 73ms/step - loss: 2.4918e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0120 - val_mean_absolute_error: 0.0871
# Epoch 37/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.2991e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0069 - val_mean_absolute_error: 0.0573
# Epoch 38/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.2379e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0075 - val_mean_absolute_error: 0.0620
# Epoch 39/80
# 30/30 [==============================] - 2s 76ms/step - loss: 2.6761e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0046 - val_mean_absolute_error: 0.0471
# Epoch 40/80
# 30/30 [==============================] - 1s 47ms/step - loss: 2.2532e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0046 - val_mean_absolute_error: 0.0490
# Epoch 41/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.2025e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0036 - val_mean_absolute_error: 0.0442
# Epoch 42/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.2749e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0034 - val_mean_absolute_error: 0.0419
# Epoch 43/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.1268e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0023 - val_mean_absolute_error: 0.0350
# Epoch 44/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.0713e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0058 - val_mean_absolute_error: 0.0597
# Epoch 45/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.3931e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 46/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.1065e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0048 - val_mean_absolute_error: 0.0528
# Epoch 47/80
# 30/30 [==============================] - 2s 73ms/step - loss: 2.0158e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0032 - val_mean_absolute_error: 0.0388
# Epoch 48/80
# 30/30 [==============================] - 2s 71ms/step - loss: 2.1942e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0033 - val_mean_absolute_error: 0.0402
# Epoch 49/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.8464e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0036 - val_mean_absolute_error: 0.0439
# Epoch 50/80
# 30/30 [==============================] - 2s 70ms/step - loss: 1.8301e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0033 - val_mean_absolute_error: 0.0406
# Epoch 51/80
# 30/30 [==============================] - 2s 66ms/step - loss: 1.9399e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0031 - val_mean_absolute_error: 0.0390
# Epoch 52/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.8763e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0026 - val_mean_absolute_error: 0.0366
# Epoch 53/80
# 30/30 [==============================] - 1s 40ms/step - loss: 1.7639e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0029 - val_mean_absolute_error: 0.0382
# Epoch 54/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.9494e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0043 - val_mean_absolute_error: 0.0471
# Epoch 55/80
# 30/30 [==============================] - 1s 47ms/step - loss: 1.7766e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0037 - val_mean_absolute_error: 0.0469
# Epoch 56/80
# 30/30 [==============================] - 1s 45ms/step - loss: 2.2636e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0020 - val_mean_absolute_error: 0.0310
# Epoch 57/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.8153e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0031 - val_mean_absolute_error: 0.0399
# Epoch 58/80
# 30/30 [==============================] - 2s 77ms/step - loss: 1.5747e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0037 - val_mean_absolute_error: 0.0438
# Epoch 59/80
# 30/30 [==============================] - 2s 75ms/step - loss: 1.6510e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0039 - val_mean_absolute_error: 0.0443
# Epoch 60/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.5751e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0032 - val_mean_absolute_error: 0.0394
# Epoch 61/80
# 30/30 [==============================] - 2s 64ms/step - loss: 1.5871e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0042 - val_mean_absolute_error: 0.0502
# Epoch 62/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7045e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0035 - val_mean_absolute_error: 0.0420
# Epoch 63/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.6342e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0351
# Epoch 64/80
# 30/30 [==============================] - 1s 43ms/step - loss: 1.6348e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0310
# Epoch 65/80
# 30/30 [==============================] - 1s 45ms/step - loss: 1.5770e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0021 - val_mean_absolute_error: 0.0322
# Epoch 66/80
# 30/30 [==============================] - 1s 43ms/step - loss: 1.4413e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0028 - val_mean_absolute_error: 0.0372
# Epoch 67/80
# 30/30 [==============================] - 1s 42ms/step - loss: 1.4725e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0040 - val_mean_absolute_error: 0.0477
# Epoch 68/80
# 30/30 [==============================] - 1s 47ms/step - loss: 1.5805e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0365
# Epoch 69/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4353e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381
# Epoch 70/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0042 - val_mean_absolute_error: 0.0486
# Epoch 71/80
# 30/30 [==============================] - 1s 46ms/step - loss: 1.6468e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0030 - val_mean_absolute_error: 0.0432
# Epoch 72/80
# 30/30 [==============================] - 1s 40ms/step - loss: 1.8102e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258
# Epoch 73/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.3750e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 74/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.3819e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0031 - val_mean_absolute_error: 0.0418
# Epoch 75/80
# 30/30 [==============================] - 2s 66ms/step - loss: 1.3267e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0020 - val_mean_absolute_error: 0.0317
# Epoch 76/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.3463e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0032 - val_mean_absolute_error: 0.0434
# Epoch 77/80
# 30/30 [==============================] - 2s 68ms/step - loss: 1.3339e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0018 - val_mean_absolute_error: 0.0314
# Epoch 78/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.3589e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0019 - val_mean_absolute_error: 0.0306
# Epoch 79/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.3870e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0029 - val_mean_absolute_error: 0.0401
# Epoch 80/80
# 30/30 [==============================] - 1s 40ms/step - loss: 1.2979e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0023 - val_mean_absolute_error: 0.0368

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 8ms/step
# array([[0.483859  , 0.48301157],
#        [0.48953602, 0.48876157],
#        [0.4950712 , 0.49422628],
#        [0.5115914 , 0.5099757 ],
#        [0.51956093, 0.51849794]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1568.0359, 1563.4447],
#        [1578.5605, 1574.1013],
#        [1588.8224, 1584.2294],
#        [1619.4495, 1613.4183],
#        [1634.2244, 1629.213 ]], dtype=float32)

# %%
gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1568.035889      1563.444702
# 2020-08-25  1582.07  1608.22     1578.560547      1574.101318
# 2020-08-26  1608.00  1652.38     1588.822388      1584.229370
# 2020-08-27  1653.68  1634.33     1619.449463      1613.418335
# 2020-08-28  1633.49  1644.41     1634.224365      1629.213013

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # Predicting upcoming 10 days

# %%
gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# Out:
# C:\Users\sr528\AppData\Local\Temp\ipykernel_5632\3327446456.py:1: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# C:\Users\sr528\AppData\Local\Temp\ipykernel_5632\3327446456.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2273.556885      2442.549072
# 2021-06-10  2494.01  2521.60     2283.181396      2457.468262
# 2021-06-11  2524.92  2513.93     2296.548340      2474.750244
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\sr528\AppData\Local\Temp\ipykernel_5632\4155468105.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\sr528\AppData\Local\Temp\ipykernel_5632\548185773.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()
